# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
array_size = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096]
cpu_time = [0.249666, 0.22247, 0.234514, 0.249563, 0.288137, 0.268594, 0.284893, 0.286567, 0.350069, 0.466372, 0.582764]
gpu_time = [0.0363241, 0.0654957, 0.135432, 0.286969, 0.578984, 1.04437, 1.95398, 3.70872, 7.06976, 13.1003, 18.3273]

# %%
mpl.rc('font',family = 'serif',size = 17)
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['xtick.minor.size'] = 2
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['ytick.minor.size'] = 2

# %%
fig, ax = plt.subplots(1,1)
ax.plot(array_size, cpu_time)
ax.plot(array_size, gpu_time)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('_shared_ memory size')
ax.set_ylabel('running time')
