# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
mpl.rc('font',family='Times New Roman',size = 15)
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['xtick.minor.size'] = 2
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['ytick.minor.size'] = 2

# %%
L = 100.
X = np.arange(0., L, 0.1)
Y = np.arange(0., L, 0.1)
x, y = np.meshgrid(X,Y)
print (np.shape(x))
print (np.shape(y))
z = []
for yy in Y:
    for xx in X:
        z.append(np.sin(xx*np.pi/L)*np.sinh(yy*np.pi/L))
z = np.reshape(z, np.shape(x))
plt.figure()
plt.contourf(x, y, z, cmap="coolwarm")
plt.colorbar()
plt.show()
# Out:
# (1000, 1000)
# (1000, 1000)

# %%
fig, axes = plt.subplots(2, 3, figsize = (17,10))
fig.subplots_adjust(hspace = 0.3, wspace = 0.3)
for i, ax in enumerate(axes.flat):
    fp = open('data'+str(i),'r')
    Z = []
    for line in fp:
        Z.append(np.array(map(float,line.split(' ')))[2])
    fp.close()
    n = int(np.sqrt(len(Z))) - 1
    dx = L/n
    X = np.arange(0., L + 0.1*dx, dx)
    Y = np.arange(0., L + 0.1*dx, dx)
    Y, X = np.meshgrid(X,Y)
    Z = np.reshape(Z, np.shape(X))
    ax.contourf(X, Y, Z, cmap="coolwarm")
plt.show()

# %%
n_grid = [10, 17, 30, 55, 100, 170, 300, 550]
t_serial = [0.32, 0.82, 2.29, 7.61, 24.4, 70., 208, 585]
t_cuda = [1.75, 1.83, 1.8, 2.08, 2.98, 5.06, 11.6, 28.1]
line1, = plt.plot(n_grid, t_serial)
line2, = plt.plot(n_grid, t_cuda)
plt.show()
