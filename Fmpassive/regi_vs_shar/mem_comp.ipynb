# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
4096*4
# Out:
# 16384

# %%
arr_size = [8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 12288]
regi = [0.20582, 0.20835, 0.21008, 0.20738, 0.20654, 0.32555, 0.32494, 0.32541, 0.32542, 0.32618, 0.27503, 0.38601]
shar = [0.16483, 0.16482, 0.16429, 0.16671, 0.15654, 0.16389, 0.16671, 0.13528, 0.16573, 0.16533, 0.12443, 0.15198]
glob = [0.38346, 0.36000, 0.36126, 0.35396, 0.30654, 0.33721, 0.34984, 0.29012, 0.35500, 0.34277, 0.31705, 0.33115]

# %%
plt.plot(arr_size, regi, label='register array (with dynamic index)')
plt.plot(arr_size, shar, label='shared array' )
plt.plot(arr_size, glob, label='global array' )
plt.legend()
plt.xscale('log')
plt.xlabel('array size')
plt.ylabel('running time (s)')
plt.show()
