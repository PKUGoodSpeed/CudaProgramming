# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
4096 * 3
# Out:
# 12288

# %%
arr_size = [8, 16, 32, 64, 128, 256, 512, 1024]
sing = [0.0267324, 0.0265907, 0.0265377, 0.0372888, 0.0417481, 0.0701278, 0.14234, 0.338854]
glob = np.array([0.159245, 0.139097, 0.175815, 0.173666, 0.177509, 0.171063, 0.177063, 0.1987])*1.7

# %%
plt.plot(arr_size, sing, label='single thread')
plt.plot(arr_size, glob, label='multiple threads to handling levels' )
plt.legen
plt.show()
